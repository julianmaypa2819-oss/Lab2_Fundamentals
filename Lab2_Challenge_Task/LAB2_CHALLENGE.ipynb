# %%
# Setup 
surname = "MAYPA"
seed_num = 7
redacted_name = ""

# Logic
for char in surname:
    if char in "AEIOU":
        redacted_name += str(seed_num)
        print(f"Vowel detected: {char} -> Replaced witj {seed_num}")
    else:
        redacted_name += char 
        print(f"Consonant detected: {char} -> Kept as {char}")

print(f"\nOriginal Surname: {surname}")
print(f"Reduced Output: {redacted_name}")
# Out:
# Consonant detected: M -> Kept as M
# Vowel detected: A -> Replaced witj 7
# Consonant detected: Y -> Kept as Y
# Consonant detected: P -> Kept as P
# Vowel detected: A -> Replaced witj 7
#
# Original Surname: MAYPA
# Reduced Output: M7YP7

# %%
# Logic 
engineer_name = "MAYPA"
first_letter = engineer_name[0]
ascii_val = ord(first_letter)
seed_num = 7
total_loops = 10  # From Task 14

verification_hash = (ascii_val * seed_num) - total_loops

print(f"First Letter: {first_letter}")
print(f"ASCII Value (A): {ascii_val}")
print(f"SEED_NUM (B): {seed_num}")
print(f"Total Loops (C): {total_loops}")
print(f"Verification Hash: {verification_hash}")
# Out:
# First Letter: M
# ASCII Value (A): 77
# SEED_NUM (B): 7
# Total Loops (C): 10
# Verification Hash: 529

# %%
# Setup 
correct_password = "TUPM_MAYPA"  # This is the "Sentinel Value"
attempts = 0
user_input = ""

print("--- SYSTEM LOCKED ---")

# Logic: Mission 3 (Indefinite Iteration)
while user_input != correct_password:
    user_input = input(f"Attempt {attempts + 1} - Enter Password: ")

    if user_input == correct_password:
        print("ACCESS GRANTED: Forensic Session Initialized.")
    else:
        attempts += 1  # Only count the failure
        print(f"ACCESS DENIED: {user_input} is incorrect.")

    print(f"\n--- Assessment Data ---")
    print(f"Correct Password Set: {correct_password}")
    print(f"Total Attempts Mode: {attempts + 1}")
    print(f"Attempts Before Success: {attempts}")
# Out:
# --- SYSTEM LOCKED ---
# ACCESS DENIED: PASSWORD is incorrect.
#
# --- Assessment Data ---
# Correct Password Set: TUPM_MAYPA
# Total Attempts Mode: 2
# Attempts Before Success: 1
# ACCESS DENIED: JULIAN is incorrect.
#
# --- Assessment Data ---
# Correct Password Set: TUPM_MAYPA
# Total Attempts Mode: 3
# Attempts Before Success: 2
# ACCESS GRANTED: Forensic Session Initialized.
#
# --- Assessment Data ---
# Correct Password Set: TUPM_MAYPA
# Total Attempts Mode: 3
# Attempts Before Success: 2
